# %%
# !pip install langchain

from langchain.tools import SerpAPIWrapper, PlaywrightBrowser
from langchain.agents import initialize_agent, Tool
from langchain.llms import OpenAI
# Out:
# Looking in indexes: https://pypi.python.org/simple/
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> get_ipython().system('pip install langchain')
# ----> <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from langchain.tools import SerpAPIWrapper, PlaywrightBrowser
# ...

# %%
#### THIS DIDN"T WORK
'''

# SerpAPI wrapper setup (Google Search)
search = SerpAPIWrapper()

# Playwright setup (for direct navigation)
browser = PlaywrightBrowser()

# Define the tools
tools = [
    Tool(
        name="Google Search",
        func=search.run,
        description="Use Google Search to answer questions."
    ),
    Tool(
        name="Browse Website",
        func=browser.run,
        description="Use browser to navigate to websites and extract information."
    )
]

# Initialize the OpenAI language model (you can use another LLM if needed)
llm = OpenAI(temperature=0)

# Create the agent with the tools
agent = initialize_agent(
    tools, 
    llm, 
    agent_type="zero-shot-react-description", 
    verbose=True
)

# Example question where either search or browsing could help
question = "What is the latest update on SpaceX launches?"

# Run the agent
response = agent.run(question)

print(response)
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # SerpAPI wrapper setup (Google Search)
# ----> <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> search = SerpAPIWrapper()
#       <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> # Playwright setup (for direct navigation)
#       <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> browser = PlaywrightBrowser()
#
# ...

# %%
# !pip install -q langchain-openai
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import getpass
import os

os.environ["OPENAI_API_KEY"] = getpass.getpass()

from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-4")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> import os
#       <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> os.environ["OPENAI_API_KEY"] = getpass.getpass()
# ----> <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> from langchain_openai import ChatOpenAI
#       <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/LangChainAgent0.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a> model = ChatOpenAI(model="gpt-4")
#
# ...

# %%
import serpapi
pm1 = serpapi.search(q="Product Manager in the last 3 days", engine="google_jobs", api_key="2ed07e54e8562266a5df0cd206c1a66ea708775e3e3c22ae96e8cac1613f2823", location="New York, NY")
a

# %%
[j['description'] for j in pm1['jobs_results']]
# Out:
# ["Position Summary...\n\nWhat you'll do...\n\n🚀 Join the Revolution in Data with Walmart Data Ventures as a Product Manager ! 🚀\n\nAre you an entrepreneurial spirit with a knack for product management? Do you thrive on the challenge of transforming raw data into actionable insights? If so, we want YOU to join our team at Walmart Data Ventures. Formed in 2021, our mission is to harness the power of Walmart's data, developing B2B data initiatives that offer merchants and suppliers an unrivaled view of omni-shoppers. We're on the lookout for a dynamic Product Manager to drive this transformation from concept to deployment.\n\nWhat you'll do...\n• E xecute the strategy and roadmap to address customer needs\n• Collaborate with cross-functional teams for seamless product development and delivery\n• Serve as the go-to-expert for product offerings, evangelizing our value proposition\n• Use insights from data to inform product improvements\n• Assess product performance metrics, identifying tr
# ...

# %%
pm1
# Out:
# {
#     "search_metadata": {
#         "id": "66f09190db3ac996d183717c",
#         "status": "Success",
#         "json_endpoint": "https://serpapi.com/searches/3c9bbd05a54c84f5/66f09190db3ac996d183717c.json",
#         "created_at": "2024-09-22 21:52:16 UTC",
#         "processed_at": "2024-09-22 21:52:16 UTC",
#         "google_jobs_url": "https://www.google.com/search?q=Product+Manager+in+the+last+3+days&uule=w+CAIQICIZTmV3IFlvcmssTlksVW5pdGVkIFN0YXRlcw&udm=8",
#         "raw_html_file": "https://serpapi.com/searches/3c9bbd05a54c84f5/66f09190db3ac996d183717c.html",
#         "total_time_taken": 0.61
#     },
#     "search_parameters": {
#         "q": "Product Manager in the last 3 days",
#         "engine": "google_jobs",
#         "location_requested": "New York, NY",
#         "location_used": "New York,NY,United States",
#         "google_domain": "google.com"
#     },
#     "filters": [
#         {
#             "name": "Remote",
#             "parameters": {
# ...

# %%
# !pwd
# Out:
# /Users/arthur/www/personal/experiments/crewai-basic/test0

# %%
run()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/arthur/www/personal/experiments/crewai-basic/test0/CrewTest2.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/arthur/www/personal/experiments/crewai-basic/test0/CrewTest2.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> run()
#
# File ~/www/personal/experiments/crewai-basic/test0/src/test2/main.py:18, in run()
#      14 inputs = {
#      15     'topic': 'AI LLMs'
#      16 }
#      17 crew0 = Test0Crew()
# ---> 18 crewcrew0 = crew0.crew()
#      19 kickoff = crewcrew0.kickoff(inputs=inputs)
#      20 return crew0, crewcrew0, kickoff
#
# File ~/www/personal/experiments/py3crew0/lib/python3.11/site-packages/crewai/project/annotations.py:104, in crew.<locals>.wrapper(self, *args, **kwargs)
#     102 # Instantiate tasks in the order they were defined
#     103 for task_name in sorted_task_names:
# ...

# %%
_7[2].tasks_output[0]
# Out:
# TaskOutput(description='Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024. Please include all web searches you perform and any websites you visit during your research.\n', name='research_task', expected_output='A list with 3 bullet points of the most relevant information about AI LLMs For each bullet point, please include a list of all web searches performed and websites visited.\n', summary='Conduct a thorough research about AI LLMs Make sure you...', raw='- **OpenAI\'s Advanced GPT-4:**\n  - OpenAI has continued to enhance its GPT-4 model, making significant strides in contextual understanding and reducing biases. The model now incorporates a more extensive dataset and advanced fine-tuning techniques, enhancing its performance across various applications, including natural language understanding, translation, and creative writing.\n  - Web Searches:\n    - "Latest developments in AI LLMs 2024"\n  - W
# ...

# %%
_24.tasks_output
# Out:
# [TaskOutput(description='Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.\n', name='research_task', expected_output='A list with 3 bullet points of the most relevant information about AI LLMs\n', summary='Conduct a thorough research about AI LLMs Make sure you...', raw="- **GPT-4.5 and Multimodal Capabilities**: One of the significant advancements in 2024 is the release of GPT-4.5 by OpenAI, which builds upon its predecessor, GPT-4. The upgraded model showcases improved language understanding and generation capabilities. A key feature of GPT-4.5 is its enhanced multimodal functionality, enabling it to process and generate content that includes text, images, and even videos. This development marks a substantial leap towards more interactive and versatile AI applications in various fields, from education to entertainment and beyond.\n\n- **Integration of LLMs in Real-Time Applications**: Another pivota
# ...

# %%
_25[0]
# Out:
# TaskOutput(description='Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.\n', name='research_task', expected_output='A list with 3 bullet points of the most relevant information about AI LLMs\n', summary='Conduct a thorough research about AI LLMs Make sure you...', raw="- **GPT-4.5 and Multimodal Capabilities**: One of the significant advancements in 2024 is the release of GPT-4.5 by OpenAI, which builds upon its predecessor, GPT-4. The upgraded model showcases improved language understanding and generation capabilities. A key feature of GPT-4.5 is its enhanced multimodal functionality, enabling it to process and generate content that includes text, images, and even videos. This development marks a substantial leap towards more interactive and versatile AI applications in various fields, from education to entertainment and beyond.\n\n- **Integration of LLMs in Real-Time Applications**: Another pivotal
# ...

# %%
_26.description
# Out:
# 'Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.\n'

# %%
_26.summary
# Out:
# 'Conduct a thorough research about AI LLMs Make sure you...'

# %%
_26.raw
# Out:
# "- **GPT-4.5 and Multimodal Capabilities**: One of the significant advancements in 2024 is the release of GPT-4.5 by OpenAI, which builds upon its predecessor, GPT-4. The upgraded model showcases improved language understanding and generation capabilities. A key feature of GPT-4.5 is its enhanced multimodal functionality, enabling it to process and generate content that includes text, images, and even videos. This development marks a substantial leap towards more interactive and versatile AI applications in various fields, from education to entertainment and beyond.\n\n- **Integration of LLMs in Real-Time Applications**: Another pivotal trend in 2024 is the widespread integration of large language models (LLMs) in real-time applications. These models are increasingly becoming integral to customer service operations, dynamic content creation, and personalized user experiences. Companies are leveraging LLMs to provide instant support, automate complex workflows, and create highly tailo
# ...

# %%
print(_26.raw)
# Out:
# - **GPT-4.5 and Multimodal Capabilities**: One of the significant advancements in 2024 is the release of GPT-4.5 by OpenAI, which builds upon its predecessor, GPT-4. The upgraded model showcases improved language understanding and generation capabilities. A key feature of GPT-4.5 is its enhanced multimodal functionality, enabling it to process and generate content that includes text, images, and even videos. This development marks a substantial leap towards more interactive and versatile AI applications in various fields, from education to entertainment and beyond.
#
# ...

# %%
dir(_26)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__class_vars__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__fields__',
#  '__fields_set__',
#  '__format__',
#  '__ge__',
#  '__get_pydantic_core_schema__',
#  '__get_pydantic_json_schema__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pretty__',
#  '__private_attributes__',
#  '__pydantic_complete__',
#  '__pydantic_core_schema__',
#  '__pydantic_custom_init__',
#  '__pydantic_decorators__',
#  '__pydantic_extra__',
#  '__pydantic_fields_set__',
#  '__pydantic_generic_metadata__',
#  '__pydantic_init_subclass__',
#  '__pydantic_parent_namespace__',
#  '__pydantic_post_init__',
#  '__pydantic_private__',
#  '__pydantic_root_model__',
# ...
